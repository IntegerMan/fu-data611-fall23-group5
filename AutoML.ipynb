# %% [markdown]
# # DATA-611 Final Project - Eland - AutoML Model Training
#
# This notebook handles training a model using auto-sklearn
#
# It starts with `train.csv` and trains a model using this dataset. The model is then saved to `model.pkl`
#
# This notebook was originally developed in Azure Machine Learning Studio against the Python 3 (ipykernel) kernel on a STANDARD_E4DS_V4 compute instance

# %% [markdown]
# ## Dependencies

# %%
# %pip install pandas
# %pip install scikit-learn
# %pip install auto-sklearn
# Out:
# Requirement already satisfied: pandas in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: auto-sklearn in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (0.15.0)
# Requirement already satisfied: numpy>=1.9.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (1.24.3)
# Requirement already satisfied: smac<1.3,>=1.2 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (1.2)
# Requirement already satisfied: dask>=2021.12 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (2023.5.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (6.0)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.21 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (0.4.21)
# Requirement already satisfied: typing-extensions in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (4.6.3)
# Requirement already satisfied: setuptools in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (65.6.3)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (0.24.2)
# Requirement already satisfied: distributed>=2012.12 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (2023.5.0)
# Requirement already satisfied: liac-arff in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (2.5.0)
# Requirement already satisfied: distro in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (1.8.0)
# Requirement already satisfied: pandas>=1.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (2.0.2)
# Requirement already satisfied: pynisher<0.7,>=0.6.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (0.6.4)
# Requirement already satisfied: joblib in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (1.3.2)
# Requirement already satisfied: threadpoolctl in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (3.2.0)
# Requirement already satisfied: scipy>=1.7.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (1.10.1)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from auto-sklearn) (0.8.3)
# Requirement already satisfied: pyparsing in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (3.1.1)
# Requirement already satisfied: cython in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (3.0.4)
# Requirement already satisfied: partd>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (1.4.1)
# Requirement already satisfied: click>=8.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (8.1.3)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (6.7.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (2023.10.0)
# Requirement already satisfied: toolz>=0.10.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (23.0)
# Requirement already satisfied: zict>=2.2.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (3.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Requirement already satisfied: tornado>=6.0.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (6.3.2)
# Requirement already satisfied: msgpack>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.0.5)
# Requirement already satisfied: tblib>=1.6.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (2.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.26.16)
# Requirement already satisfied: locket>=1.0.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (3.0.3)
# Requirement already satisfied: psutil>=5.7.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (5.9.5)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2023.3)
# Requirement already satisfied: emcee>=3.0.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn) (3.1.4)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from importlib-metadata>=4.13.0->dask>=2021.12->auto-sklearn) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from jinja2>=2.10.3->distributed>=2012.12->auto-sklearn) (2.0.1)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/jupyter_env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.0->auto-sklearn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data Loading
#
# Load our train.csv file

# %%
import pandas as pd

df_train = pd.read_csv('train.csv', index_col=0)
df_train.head()
# Out:
#        Credit Amount  Repay Delay Sep  Repay Delay Aug  Repay Delay Jul  \
# 14720         130000                0                0                0
# 2522          200000                0                0                0
# 24918          90000                0                0                0
# 35444         200000                0                0                0
# 7608          260000                0                0                0
#
#        Prior Pay Sep  Prior Pay Aug  Prior Pay Jul  Graduate School  \
# 14720          10000          10000          15000                0
# 2522             753            547              2                0
# 24918           1968           1968           1218                0
# 35444            372            865             23                1
# 7608           10027          10107          20000                1
#
#        Is Married  Prior Pay Total  Repay Delay Total  Defaulted
# 14720       False            70000                  0      False
# 2522        False             3344                  0      False
# 24918       False             8132                  0       True
# 35444       False            72777                  0       True
# 7608         True            70134                  0      False

# %%
# Split our label column from the rest of the data
X_train = df_train.drop(columns=['Defaulted'])
y_train = df_train['Defaulted']

# %% [markdown]
# ## Automated ML Model Training

# %%
# Create a pipeline using auto-sklearn to auto-select the best model
import autosklearn.classification
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# This should be the same as the number of CPU cores of the machine running the notebook
num_cores = 4

training_minutes = 180

# Auto scikit-learn lets us find optimal algorithm and hyperparameter combinations
classifier = autosklearn.classification.AutoSklearnClassifier(time_left_for_this_task=training_minutes * 60,  
                                                              n_jobs=num_cores, 
                                                              metric=autosklearn.metrics.f1
                                                              )

# Create a pipeline that scales the data and trains a logistic regression model
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', classifier)
])
pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                                        metric=f1, n_jobs=4,
#                                        time_left_for_this_task=10800))])

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# Display info on the classifier
classifier
# Out:
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       metric=f1, n_jobs=4, per_run_time_limit=4320,
#                       time_left_for_this_task=10800)

# %% [markdown]
# ### Evaluated Models

# %%
# Display the leaderboard
classifier.leaderboard()
# Out:
#           rank  ensemble_weight               type      cost    duration
# model_id
# 312          1             0.04  gradient_boosting  0.188775   37.328512
# 176          2             0.06  gradient_boosting  0.190801   33.657909
# 469          3             0.04  gradient_boosting  0.190929   43.874617
# 751          4             0.06  gradient_boosting  0.191211   29.784710
# 684          5             0.02  gradient_boosting  0.191227   48.822893
# 736          6             0.08  gradient_boosting  0.191533   39.896581
# 692          7             0.02  gradient_boosting  0.191609   37.488533
# 666          8             0.14  gradient_boosting  0.192243   34.652723
# 695          9             0.02  gradient_boosting  0.192250   37.027887
# 661         10             0.06  gradient_boosting  0.192369   37.656005
# 722         11             0.02  gradient_boosting  0.192404   34.724431
# 229         12             0.02  gradient_boosting  0.192655   52.113459
# 639         13             0.02  gradient_boosting  0.192756   34.945801
# 493         14             0.02  gradient_boosting  0.192986   39.809637
# 311         15             0.08  gradient_boosting  0.193254  101.888010
# 191         16             0.14  gradient_boosting  0.193317  103.276103
# 353         17             0.02  gradient_boosting  0.193332   38.953808
# 443         18             0.14  gradient_boosting  0.193849   86.005936

# %%
# Enable pretty printing
from pprint import pprint

# Pretty print the classifier model
pprint(classifier.show_models(), indent=3)
# Out:
# {  176: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f540a765c10>,
#            'cost': 0.19080115920351504,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f5421d16b50>,
#            'ensemble_weight': 0.06,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f540a765d30>,
#            'model_id': 176,
#            'rank': 1,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.3814598105175607e-08,
#                                learning_rate=0.13979963154620015, max_iter=512,
#                                max_leaf_nodes=321, min_samples_leaf=3,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    191: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f540aa28700>,
#            'cost': 0.19331653131709137,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f5409c9a4c0>,
#            'ensemble_weight': 0.14,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f540a751d60>,
#            'model_id': 191,
#            'rank': 2,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=7.788331134652818e-08,
#                                learning_rate=0.19071071171557002, max_iter=512,
#                                max_leaf_nodes=357, min_samples_leaf=3,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    229: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f540a383400>,
#            'cost': 0.19265541989001767,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f5420e69dc0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f540a383f10>,
#            'model_id': 229,
#            'rank': 3,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=7.638747153286812e-08,
#                                learning_rate=0.18345951057200732, max_iter=512,
#                                max_leaf_nodes=434, min_samples_leaf=1,
#                                n_iter_no_change=20, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    311: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f5407c28550>,
#            'cost': 0.193253820350354,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f540bc782b0>,
#            'ensemble_weight': 0.08,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f5407c28b50>,
#            'model_id': 311,
#            'rank': 4,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=1.3608249703631952e-07,
#                                learning_rate=0.18107502191392058, max_iter=512,
#                                max_leaf_nodes=371, min_samples_leaf=1,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    312: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ecd6b3a0>,
#            'cost': 0.18877455565949486,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53fdb9f9d0>,
#            'ensemble_weight': 0.04,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ecd6b2e0>,
#            'model_id': 312,
#            'rank': 5,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.3622938103238853e-08,
#                                learning_rate=0.15119968921817978, max_iter=512,
#                                max_leaf_nodes=336, min_samples_leaf=1,
#                                n_iter_no_change=18, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    353: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ecc0ee50>,
#            'cost': 0.19333209163717624,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f5423816520>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ecc0ed00>,
#            'model_id': 353,
#            'rank': 6,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.3735741084546771e-07,
#                                learning_rate=0.1891068591123206, max_iter=512,
#                                max_leaf_nodes=392, min_samples_leaf=1,
#                                n_iter_no_change=19, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    443: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53eca47850>,
#            'cost': 0.1938490214352283,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ecdda430>,
#            'ensemble_weight': 0.14,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53eca476d0>,
#            'model_id': 443,
#            'rank': 7,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.3349108840359144e-10,
#                                learning_rate=0.057116993083435534, max_iter=512,
#                                max_leaf_nodes=295, min_samples_leaf=1,
#                                n_iter_no_change=9, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    469: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ec89d580>,
#            'cost': 0.19092945128779404,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ecbfddf0>,
#            'ensemble_weight': 0.04,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ec89d4c0>,
#            'model_id': 469,
#            'rank': 8,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=1.8371182199151215e-10,
#                                learning_rate=0.14918949413554133, max_iter=512,
#                                max_leaf_nodes=444, min_samples_leaf=2,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    493: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ec680130>,
#            'cost': 0.19298572894319566,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53eca36820>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ec670f70>,
#            'model_id': 493,
#            'rank': 9,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=7.788331134652818e-08,
#                                learning_rate=0.1892790639198036, max_iter=512,
#                                max_leaf_nodes=346, min_samples_leaf=2,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    639: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ec4d7af0>,
#            'cost': 0.19275646410902647,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ec8895b0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ec4d7970>,
#            'model_id': 639,
#            'rank': 10,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=4.671902915871893e-07,
#                                learning_rate=0.1892790639198036, max_iter=512,
#                                max_leaf_nodes=346, min_samples_leaf=2,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    661: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ec2a0550>,
#            'cost': 0.19236854350860866,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ec66b070>,
#            'ensemble_weight': 0.06,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ec2a03d0>,
#            'model_id': 661,
#            'rank': 11,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.689828188769966e-08,
#                                learning_rate=0.18840318427966946, max_iter=512,
#                                max_leaf_nodes=340, min_samples_leaf=1,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    666: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53ec057f40>,
#            'cost': 0.19224314749207538,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ec4c3a60>,
#            'ensemble_weight': 0.14,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53ec057dc0>,
#            'model_id': 666,
#            'rank': 12,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=1.2916800227406782e-08,
#                                learning_rate=0.1639001373153397, max_iter=512,
#                                max_leaf_nodes=356, min_samples_leaf=2,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    684: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53e7d8a940>,
#            'cost': 0.1912272515165655,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ec280490>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53e7d8a7c0>,
#            'model_id': 684,
#            'rank': 13,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.1507919028934437e-08,
#                                learning_rate=0.17776173051507888, max_iter=512,
#                                max_leaf_nodes=405, min_samples_leaf=1,
#                                random_state=1, validation_fraction=None,
#                                warm_start=True)},
#    692: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53e7b5f280>,
#            'cost': 0.19160891552725223,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53ec03ee80>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53e7b5f190>,
#            'model_id': 692,
#            'rank': 14,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.514257662107636e-08,
#                                learning_rate=0.165035874380821, max_iter=512,
#                                max_leaf_nodes=327, min_samples_leaf=2,
#                                n_iter_no_change=18, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    695: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f53e7917d30>,
#            'cost': 0.19225009359790335,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53e7def8b0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f53e7917bb0>,
#            'model_id': 695,
#            'rank': 15,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.1192733502623985e-08,
#                                learning_rate=0.15650728079587975, max_iter=512,
#                                max_leaf_nodes=334, min_samples_leaf=2,
#                                n_iter_no_change=8, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    722: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f5421893490>,
#            'cost': 0.19240435632504882,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53e7bbe2e0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f5421893a90>,
#            'model_id': 722,
#            'rank': 16,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=3.4735431619011e-08,
#                                learning_rate=0.17682888181979112, max_iter=512,
#                                max_leaf_nodes=387, min_samples_leaf=1,
#                                n_iter_no_change=0, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    736: {  'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f5409ce9580>,
#            'cost': 0.1915330100708692,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f53e797cc70>,
#            'ensemble_weight': 0.08,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f5409ce9f70>,
#            'model_id': 736,
#            'rank': 17,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5553698576790167e-08,
#                                learning_rate=0.17785741383355358, max_iter=512,
#                                max_leaf_nodes=385, min_samples_leaf=1,
#                                n_iter_no_change=8, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#    751: {  'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f5408cfabb0>,
#            'cost': 0.19121084618980821,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f5420d09a90>,
#            'ensemble_weight': 0.06,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f5408cfa5b0>,
#            'model_id': 751,
#            'rank': 18,
#            'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.6124032452568446e-08,
#                                learning_rate=0.15884361326270122, max_iter=512,
#                                max_leaf_nodes=337, min_samples_leaf=1,
#                                n_iter_no_change=19, random_state=1,
#                                validation_fraction=None, warm_start=True)}}

# %% [markdown]
# ### Model Serialization
#
# Now that we have a model, let's serialize it to disk using Pickel so we can evaluate it in a different notebook

# %%
import pickle

pickle.dump(pipeline, open('model.pkl', 'wb'))

# %% [markdown]
# Work continues from `ModelMetrics.ipynb`
